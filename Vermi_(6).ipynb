# %% [markdown]
# # #**VeReMi: A Dataset for Comparable Evaluation of Misbehavior Detection in VANETs**

# %% [markdown]
# About Dataset
# The VeReMi dataset is created to assess the effectiveness of misbehavior detection methods in Vehicular Ad-HocNetworks (VANETs). It comprises message logs from onboard units, accompanied by a labeled ground truth generated from a simulated environment. The dataset includes malicious messages that cause incorrect application behavior, which the misbehavior detection mechanisms aim to prevent. The initial release of the VeReMidataset contains simple attacks, but it seeks to be a starting point for more complex attacks. The message logs of each vehicle contain GPS data (labeled as type=2) about the local car and Basic Safety Messages (BSM) (labeled as type=3) received from other vehicles via Dedicated Short-Range Communications (DSRC).
# The VeReMi dataset has two primary objectives. Firstly, it serves as a benchmark for evaluating the performance of misbehavior detection mechanisms on a city-wide scale. Secondly, it saves computational resources typically required to run VEINS frequently. The VeReMi dataset contains different density levels, attacks, and attacker densities. VeReMi-extension, or VeReMi, is a dataset created to test and compare different methods of identifying VANET activity. The VeReMi dataset is an invaluable resource for researchers interested in evaluating and enhancing the effectiveness of misbehavior detection mechanisms for VANETs.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('/content/mini_vermi.csv')

# %%
df
# Out:
#         Unnamed: 0.1  Unnamed: 0  type       rcvTime        pos_0  \
# 0                  0           0     3  27371.216284   981.098535
# 1                  1           1     3  52060.561117  1213.025174
# 2                  2           2     3  28156.319142   140.514133
# 3                  3           3     3  28671.375689   558.005547
# 4                  4           4     2  53612.000000   689.179631
# ...              ...         ...   ...           ...          ...
# 876207        876207      876207     3  28533.665139  1340.464657
# 876208        876208      876208     3  28319.724269   130.157308
# 876209        876209      876209     3  27682.552555   143.719030
# 876210        876210      876210     3  52565.945713   266.595865
# 876211        876211      876211     3  26498.492862   996.326024
#
#               pos_1  pos_noise_0  pos_noise_1      spd_0      spd_1  ...  \
# 0        908.497891     3.826423     3.964059 -17.723786  -2.154895  ...
# 1        984.277524     4.477449     4.459375  14.504808   2.605276  ...
# 2        944.338854     2.965184     3.066191  -0.346027   4.671520  ...
# 3        327.316562     4.934159     5.037039  11.792797   4.028876  ...
# 4        547.143780     3.327547     3.374621   3.887137  -8.732709  ...
# ...             ...          ...          ...        ...        ...  ...
# 876207  1048.671933     3.859606     3.907600  -6.848793 -11.551511  ...
# 876208   995.076583     3.486356     3.749108  -0.766734  10.350634  ...
# 876209   887.310944     4.421636     4.377972  -5.554424  -0.528734  ...
# 876210    67.232867     3.069361     3.244845  -0.891473   5.846726  ...
# 876211   919.139770     4.771749     4.939815 -14.046139  -5.797809  ...
#
#            acl_0     acl_1  acl_noise_0   acl_noise_1     hed_0     hed_1  \
# 0      -0.248402 -0.177659     0.000784  1.114785e-03 -0.971331 -0.237732
# 1      -0.653850 -0.117125     0.000001  1.847528e-07  0.992578  0.121610
# 2       0.333247 -4.486889     0.000448  6.050771e-03  0.256103  0.966649
# 3      -0.030639 -0.010265     0.000066  2.237617e-05  0.954113  0.299446
# 4      -1.829939  4.111129     0.000028  6.361425e-05  0.360402 -0.932797
# ...          ...       ...          ...           ...       ...       ...
# 876207  0.997106  1.681710     0.000124  2.098039e-04 -0.532838 -0.846217
# 876208  0.199319 -2.687823     0.000094  1.272495e-03 -0.065986  0.997821
# 876209  1.934379  0.184645     0.001044  9.951530e-05 -0.997882 -0.065056
# 876210  0.293334 -1.921998     0.000767  3.474784e-03 -0.148132  0.988968
# 876211 -0.109785 -0.045148     0.001051  3.560000e-03       NaN       NaN
#
#         hed_noise_0  hed_noise_1  attack        attack_type
# 0         44.022409    33.840519     0.0  RandomSpeedOffset
# 1          2.560114     8.414909     0.0         DataReplay
# 2         15.915074     9.636057     1.0      DoSDisruptive
# 3          2.854203     6.203941     1.0  RandomSpeedOffset
# 4          5.648109    19.951521     0.0                DoS
# ...             ...          ...     ...                ...
# 876207    13.225309    21.166170     1.0  RandomSpeedOffset
# 876208     0.972835     0.320050     1.0    DataReplaySybil
# 876209     4.129481     2.498231     1.0           ConstPos
# 876210     4.819173     2.456610     1.0    DataReplaySybil
# 876211          NaN          NaN     NaN                NaN
#
# [876212 rows x 22 columns]

# %%
df.attack_type.value_counts()
# Out:
# attack_type
# GridSybil             49318
# DoSDisruptive         48573
# DoSRandom             48467
# DoS                   48160
# DoSDisruptiveSybil    46877
# DoSRandomSybil        46797
# Disruptive            45540
# DataReplaySybil       45349
# ConstSpeed            45334
# RandomSpeedOffset     45328
# ConstPosOffset        45284
# RandomSpeed           45273
# EventualStop          45270
# RandomPosOffset       45215
# ConstPos              45201
# RandomPos             45198
# DataReplay            45087
# ConstSpeedOffset      45023
# DelayedMessages       44917
# Name: count, dtype: int64

# %%
df['attack_type'].replace({'EventualStop': 0, 'GridSybil': 0,'DoSRandom':0, 'DoSDisruptiveSybil':0,'DelayedMessages':0,
                            'Disruptive':0, 'DoSDisruptive':0,'DataReplaySybil':0,'DataReplay':0 , 'DoSRandomSybil':0,
                            'DoS':0,

                            'ConstSpeedOffset':1 , 'ConstSpeed':1 , 'RandomSpeed':1 , 'RandomSpeedOffset':1  ,'RandomPos':1 ,
                            'ConstPos':1 ,'ConstPosOffset':1 , 'RandomPosOffset':1 ,

                           } , inplace=True)

df['attack_type'].value_counts()
# d.value_counts()
# Out:
# attack_type
# 0.0    514355
# 1.0    361856
# Name: count, dtype: int64

# %%
df.attack.value_counts()
# Out:
# attack
# 0.0    479344
# 1.0    396867
# Name: count, dtype: int64

# %%
# # Import label encoder
# from sklearn import preprocessing

# # label_encoder object knows
# # how to understand word labels.
# label_encoder = preprocessing.LabelEncoder()

# # Encode labels in column 'species'.
# df.attack_type= label_encoder.fit_transform(df.attack_type)

# df.attack_type.unique()

# %%
# df.drop(['Unnamed: 0', 'type','attack_type',"Unnamed: 0.1"],axis=1,inplace=True)

# %%
df.shape
# Out:
# (876212, 22)

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  type       rcvTime        pos_0       pos_1  \
# 0             0           0     3  27371.216284   981.098535  908.497891
# 1             1           1     3  52060.561117  1213.025174  984.277524
# 2             2           2     3  28156.319142   140.514133  944.338854
# 3             3           3     3  28671.375689   558.005547  327.316562
# 4             4           4     2  53612.000000   689.179631  547.143780
#
#    pos_noise_0  pos_noise_1      spd_0     spd_1  ...     acl_0     acl_1  \
# 0     3.826423     3.964059 -17.723786 -2.154895  ... -0.248402 -0.177659
# 1     4.477449     4.459375  14.504808  2.605276  ... -0.653850 -0.117125
# 2     2.965184     3.066191  -0.346027  4.671520  ...  0.333247 -4.486889
# 3     4.934159     5.037039  11.792797  4.028876  ... -0.030639 -0.010265
# 4     3.327547     3.374621   3.887137 -8.732709  ... -1.829939  4.111129
#
#    acl_noise_0   acl_noise_1     hed_0     hed_1  hed_noise_0  hed_noise_1  \
# 0     0.000784  1.114785e-03 -0.971331 -0.237732    44.022409    33.840519
# 1     0.000001  1.847528e-07  0.992578  0.121610     2.560114     8.414909
# 2     0.000448  6.050771e-03  0.256103  0.966649    15.915074     9.636057
# 3     0.000066  2.237617e-05  0.954113  0.299446     2.854203     6.203941
# 4     0.000028  6.361425e-05  0.360402 -0.932797     5.648109    19.951521
#
#    attack  attack_type
# 0     0.0          1.0
# 1     0.0          0.0
# 2     1.0          0.0
# 3     1.0          1.0
# 4     0.0          0.0
#
# [5 rows x 22 columns]

# %% [markdown]
# All contineous features

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 876212 entries, 0 to 876211
# Data columns (total 22 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0.1  876212 non-null  int64
#  1   Unnamed: 0    876212 non-null  int64
#  2   type          876212 non-null  int64
#  3   rcvTime       876212 non-null  float64
#  4   pos_0         876212 non-null  float64
#  5   pos_1         876212 non-null  float64
#  6   pos_noise_0   876212 non-null  float64
#  7   pos_noise_1   876212 non-null  float64
#  8   spd_0         876212 non-null  float64
#  9   spd_1         876212 non-null  float64
#  10  spd_noise_0   876212 non-null  float64
#  11  spd_noise_1   876212 non-null  float64
#  12  acl_0         876212 non-null  float64
#  13  acl_1         876212 non-null  float64
#  14  acl_noise_0   876212 non-null  float64
#  15  acl_noise_1   876212 non-null  float64
#  16  hed_0         876211 non-null  float64
#  17  hed_1         876211 non-null  float64
#  18  hed_noise_0   876211 non-null  float64
#  19  hed_noise_1   876211 non-null  float64
#  20  attack        876211 non-null  float64
#  21  attack_type   876211 non-null  float64
# dtypes: float64(19), int64(3)
# memory usage: 147.1 MB

# %% [markdown]
# Dtype - Float

# %%
df.isna().sum()
# Out:
# Unnamed: 0.1    0
# Unnamed: 0      0
# type            0
# rcvTime         0
# pos_0           0
# pos_1           0
# pos_noise_0     0
# pos_noise_1     0
# spd_0           0
# spd_1           0
# spd_noise_0     0
# spd_noise_1     0
# acl_0           0
# acl_1           0
# acl_noise_0     0
# acl_noise_1     0
# hed_0           1
# hed_1           1
# hed_noise_0     1
# hed_noise_1     1
# attack          1
# attack_type     1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
## Plot desnity plot for all features
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn')
df.hist(bins=50,figsize=(20,15),color='orange')
plt.show()

# %%
# df.isna().sum()

# %%
# df.drop(['attack_type'],axis=1,inplace=True)

# %% [markdown]
# No null value

# %%
## Check for multicollinearity
plt.figure(figsize=(18,10))
corr=df.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 876211 entries, 0 to 876210
# Data columns (total 22 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0.1  876211 non-null  int64
#  1   Unnamed: 0    876211 non-null  int64
#  2   type          876211 non-null  int64
#  3   rcvTime       876211 non-null  float64
#  4   pos_0         876211 non-null  float64
#  5   pos_1         876211 non-null  float64
#  6   pos_noise_0   876211 non-null  float64
#  7   pos_noise_1   876211 non-null  float64
#  8   spd_0         876211 non-null  float64
#  9   spd_1         876211 non-null  float64
#  10  spd_noise_0   876211 non-null  float64
#  11  spd_noise_1   876211 non-null  float64
#  12  acl_0         876211 non-null  float64
#  13  acl_1         876211 non-null  float64
#  14  acl_noise_0   876211 non-null  float64
#  15  acl_noise_1   876211 non-null  float64
#  16  hed_0         876211 non-null  float64
#  17  hed_1         876211 non-null  float64
#  18  hed_noise_0   876211 non-null  float64
#  19  hed_noise_1   876211 non-null  float64
#  20  attack        876211 non-null  float64
#  21  attack_type   876211 non-null  float64
# dtypes: float64(19), int64(3)
# memory usage: 153.8 MB

# %%
# df.to_csv('Clean-vermi-Mini.csv')

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
x,y=train_test_split(df,test_size=0.90,random_state=2529)

# %%
x.head()
# Out:
#         Unnamed: 0.1  Unnamed: 0  type       rcvTime        pos_0       pos_1  \
# 451416        451416      451416     3  25500.993622   609.789173  832.173345
# 611464        611464      611464     3  51540.382711  1294.179977  994.786341
# 370164        370164      370164     3  27117.475174  1030.727224  929.256027
# 348861        348861      348861     3  26567.432093   261.848684  116.456756
# 155696        155696      155696     3  51960.049438   419.673644  272.614307
#
#         pos_noise_0  pos_noise_1      spd_0      spd_1  ...     acl_0  \
# 451416     4.381969     4.196216   9.331610  10.097451  ... -0.314266
# 611464     4.547467     4.548336  10.151017   8.590531  ... -0.317105
# 370164     4.066207     3.987201 -13.768340  -3.525900  ...  0.120155
# 348861     4.241109     4.193548  -2.150285  13.068592  ...  0.162374
# 155696     4.089167     3.931988 -13.814447  -4.769571  ... -0.028135
#
#            acl_1  acl_noise_0  acl_noise_1     hed_0     hed_1  hed_noise_0  \
# 451416 -0.340131     0.000055     0.000059  0.717922  0.696124     5.880541
# 611464 -0.268288     0.004987     0.009092  0.763744  0.645520     0.050288
# 370164  0.030800     0.000011     0.000009 -0.959939  0.280210    71.415208
# 348861 -0.986509     0.000017     0.000003 -0.156432  0.987689     3.609805
# 155696 -0.009548     0.000040     0.000014 -0.997818 -0.066019    31.923567
#
#         hed_noise_1  attack  attack_type
# 451416     5.446998     0.0          0.0
# 611464     0.058781     1.0          0.0
# 370164    25.642903     1.0          0.0
# 348861     0.788018     0.0          0.0
# 155696    12.921039     0.0          1.0
#
# [5 rows x 22 columns]

# %%
x.shape
# Out:
# (87621, 22)

# %%
#  'pos_noise_0', 'pos_noise_1','acl_noise_0', 'acl_noise_1',  'hed_noise_0',
#        'hed_noise_1'
# X=x[[ 'rcvTime','pos_0', 'pos_1'  , 'spd_0', 'spd_1', 'spd_noise_0', 'spd_noise_1', 'acl_0',
#        'acl_1','hed_0', 'hed_1']]

X=x.drop(['attack_type','attack'],axis=1)
y=x['attack_type']

# %%
X.shape
# Out:
# (87621, 20)

# %%
pd.DataFrame(X)
# Out:
#         Unnamed: 0.1  Unnamed: 0  type       rcvTime        pos_0       pos_1  \
# 451416        451416      451416     3  25500.993622   609.789173  832.173345
# 611464        611464      611464     3  51540.382711  1294.179977  994.786341
# 370164        370164      370164     3  27117.475174  1030.727224  929.256027
# 348861        348861      348861     3  26567.432093   261.848684  116.456756
# 155696        155696      155696     3  51960.049438   419.673644  272.614307
# ...              ...         ...   ...           ...          ...         ...
# 389860        389860      389860     2  52744.000000   631.043182  696.786222
# 153999        153999      153999     3  50805.239524   229.540928  826.410012
# 101180        101180      101180     3  26015.483903   137.216809  908.393906
# 597554        597554      597554     3  28058.854226   265.741190   46.431627
# 275808        275808      275808     3  28363.022926   357.936533  254.503632
#
#         pos_noise_0  pos_noise_1      spd_0      spd_1  spd_noise_0  \
# 451416     4.381969     4.196216   9.331610  10.097451    -0.009161
# 611464     4.547467     4.548336  10.151017   8.590531    -0.019799
# 370164     4.066207     3.987201 -13.768340  -3.525900     0.007447
# 348861     4.241109     4.193548  -2.150285  13.068592     0.001227
# 155696     4.089167     3.931988 -13.814447  -4.769571    -0.022308
# ...             ...          ...        ...        ...          ...
# 389860     4.058848     4.515759   7.687233   3.594019     0.021609
# 153999     3.635681     3.532357  -2.390075  14.513380     0.009837
# 101180     4.958636     5.158400  -0.880502  11.887803     0.001520
# 597554     3.922711     3.961901  -0.852103   8.246107    -0.000680
# 275808     3.636419     3.552463  13.977399   5.291445     0.048650
#
#         spd_noise_1     acl_0     acl_1  acl_noise_0  acl_noise_1     hed_0  \
# 451416    -0.009912 -0.314266 -0.340131     0.000055     0.000059  0.717922
# 611464    -0.016756 -0.317105 -0.268288     0.004987     0.009092  0.763744
# 370164     0.001908  0.120155  0.030800     0.000011     0.000009 -0.959939
# 348861    -0.007456  0.162374 -0.986509     0.000017     0.000003 -0.156432
# 155696    -0.007702 -0.028135 -0.009548     0.000040     0.000014 -0.997818
# ...             ...       ...       ...          ...          ...       ...
# 389860     0.010097  1.933200  0.904251     0.005171     0.002325  0.916158
# 153999    -0.059687  0.040694 -0.235194     0.000031     0.000188 -0.054569
# 101180    -0.020512 -0.203350  2.745385     0.000073     0.004248 -0.010242
# 597554     0.006585 -0.213424  2.065682     0.000154     0.001492 -0.082124
# 275808     0.018409  0.317849  0.120935     0.000108     0.000041  0.954696
#
#            hed_1  hed_noise_0  hed_noise_1
# 451416  0.696124     5.880541     5.446998
# 611464  0.645520     0.050288     0.058781
# 370164  0.280210    71.415208    25.642903
# 348861  0.987689     3.609805     0.788018
# 155696 -0.066019    31.923567    12.921039
# ...          ...          ...          ...
# 389860  0.400817     1.528615     2.301781
# 153999  0.998510    11.679128     2.154283
# 101180  0.999948     7.970154     2.223035
# 597554  0.996622    17.447163     7.024163
# 275808  0.297582     2.047270     4.879793
#
# [87621 rows x 20 columns]

# %%
# x.to_csv('X.csv')

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=2529,stratify=y)

# %%
X_train.shape
# Out:
# (61334, 20)

# %%
X_train.info(), X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61334 entries, 29062 to 504811
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  61334 non-null  int64
#  1   Unnamed: 0    61334 non-null  int64
#  2   type          61334 non-null  int64
#  3   rcvTime       61334 non-null  float64
#  4   pos_0         61334 non-null  float64
#  5   pos_1         61334 non-null  float64
#  6   pos_noise_0   61334 non-null  float64
#  7   pos_noise_1   61334 non-null  float64
#  8   spd_0         61334 non-null  float64
#  9   spd_1         61334 non-null  float64
#  10  spd_noise_0   61334 non-null  float64
#  11  spd_noise_1   61334 non-null  float64
#  12  acl_0         61334 non-null  float64
#  13  acl_1         61334 non-null  float64
#  14  acl_noise_0   61334 non-null  float64
#  15  acl_noise_1   61334 non-null  float64
#  16  hed_0         61334 non-null  float64
#  17  hed_1         61334 non-null  float64
#  18  hed_noise_0   61334 non-null  float64
#  19  hed_noise_1   61334 non-null  float64
# dtypes: float64(17), int64(3)
# memory usage: 9.8 MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 26287 entries, 823400 to 148426
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  26287 non-null  int64
#  1   Unnamed: 0    26287 non-null  int64
#  2   type          26287 non-null  int64
#  3   rcvTime       26287 non-null  float64
#  4   pos_0         26287 non-null  float64
#  5   pos_1         26287 non-null  float64
#  6   pos_noise_0   26287 non-null  float64
#  7   pos_noise_1   26287 non-null  float64
#  8   spd_0         26287 non-null  float64
#  9   spd_1         26287 non-null  float64
#  10  spd_noise_0   26287 non-null  float64
#  11  spd_noise_1   26287 non-null  float64
#  12  acl_0         26287 non-null  float64
#  13  acl_1         26287 non-null  float64
#  14  acl_noise_0   26287 non-null  float64
#  15  acl_noise_1   26287 non-null  float64
#  16  hed_0         26287 non-null  float64
#  17  hed_1         26287 non-null  float64
#  18  hed_noise_0   26287 non-null  float64
#  19  hed_noise_1   26287 non-null  float64
# dtypes: float64(17), int64(3)
# memory usage: 4.2 MB
# (None, None)

# %%
y_train.value_counts(),y_test.value_counts()
# Out:
# (attack_type
#  0.0    35879
#  1.0    25455
#  Name: count, dtype: int64,
#  attack_type
#  0.0    15378
#  1.0    10909
#  Name: count, dtype: int64)

# %%
# # Feature Selection based on correlaltion
# X_train.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
## Check for multicollinearity
# plt.figure(figsize=(12,10))

# corr=X_train.corr()
# sns.heatmap(corr,annot=True)

# %%
# def correlation(dataset, threshold):
#     col_corr = set()
#     corr_matrix = dataset.corr()
#     for i in range(len(corr_matrix.columns)):
#         for j in range(i):
#             if abs(corr_matrix.iloc[i, j]) > threshold:
#                 colname = corr_matrix.columns[i]
#                 col_corr.add(colname)
#     return col_corr

# %%
## threshold--Domain expertise
# corr_features=correlation(X_train,0.70)

# %%
# corr_features

# %%
## drop features when correlation is more than 0.85
# X_train.drop(corr_features,axis=1,inplace=True)
# X_test.drop(corr_features,axis=1,inplace=True)
# X_train.shape,X_test.shape

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
scaler=StandardScaler()
mm=MinMaxScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
pd.DataFrame(X_train_scaled).describe()
# Out:
#                  0             1             2             3             4   \
# count  6.133400e+04  6.133400e+04  6.133400e+04  6.133400e+04  6.133400e+04
# mean  -9.267848e-18 -9.267848e-18  2.904312e-16  1.028152e-16 -6.394815e-17
# std    1.000008e+00  1.000008e+00  1.000008e+00  1.000008e+00  1.000008e+00
# min   -1.727029e+00 -1.727029e+00 -2.506510e+00 -1.073086e+00 -8.896872e+00
# 25%   -8.729420e-01 -8.729420e-01  3.989611e-01 -9.145310e-01 -8.178827e-01
# 50%   -1.548336e-03 -1.548336e-03  3.989611e-01 -8.008358e-01 -6.291103e-01
# 75%    8.696336e-01  8.696336e-01  3.989611e-01  1.078898e+00  8.951789e-01
# max    1.724823e+00  1.724823e+00  3.989611e-01  1.260346e+00  5.366927e+00
#
#                  5             6             7             8             9   \
# count  6.133400e+04  6.133400e+04  6.133400e+04  6.133400e+04  6.133400e+04
# mean  -3.454011e-16  7.819747e-18  8.341063e-18  5.329013e-18 -9.152000e-18
# std    1.000008e+00  1.000008e+00  1.000008e+00  1.000008e+00  1.000008e+00
# min   -5.667285e+00 -1.034371e-01 -1.034442e-01 -3.027142e+00 -2.907706e+00
# 25%   -8.500308e-01 -1.684731e-02 -1.692741e-02 -3.805343e-01 -5.862267e-01
# 50%    1.754509e-01 -4.614876e-03 -4.572948e-03 -1.272110e-01 -1.856763e-01
# 75%    7.738101e-01  7.915859e-03  8.009197e-03  3.414797e-01  6.074705e-01
# max    7.417249e+00  2.469577e+02  2.469583e+02  4.123903e+00  3.914636e+00
#
#                  10            11            12            13            14  \
# count  6.133400e+04  6.133400e+04  6.133400e+04  6.133400e+04  6.133400e+04
# mean   4.402228e-18 -1.830400e-17  5.792405e-20  5.560709e-18  4.321134e-17
# std    1.000008e+00  1.000008e+00  1.000008e+00  1.000008e+00  1.000008e+00
# min   -7.137618e+00 -6.795868e+00 -4.849541e+00 -3.819712e+00 -3.275748e-01
# 25%   -2.021727e-01 -3.113717e-01 -2.207147e-01 -1.960076e-01 -3.256775e-01
# 50%   -3.082669e-03  7.225418e-03 -4.172209e-02 -2.495617e-02 -3.010814e-01
# 75%    2.120182e-01  3.121141e-01  1.812416e-01  2.308161e-01 -1.437211e-01
# max    7.637102e+00  6.093821e+00  4.767672e+00  3.770280e+00  2.855332e+01
#
#                  15            16            17            18            19
# count  6.133400e+04  6.133400e+04  6.133400e+04  6.133400e+04  6.133400e+04
# mean  -1.077387e-17 -1.031048e-17  2.618167e-17  2.143190e-17 -1.227990e-16
# std    1.000008e+00  1.000008e+00  1.000008e+00  1.000008e+00  1.000008e+00
# min   -3.848156e-01 -1.454709e+00 -1.382163e+00 -6.508663e-01 -6.270120e-01
# 25%   -3.827324e-01 -9.146536e-01 -1.084027e+00 -4.610505e-01 -4.616337e-01
# 50%   -3.590586e-01  6.444631e-02  2.802184e-02 -2.016525e-01 -2.438018e-01
# 75%   -8.803846e-02  4.058644e-01  1.095000e+00  1.785517e-01  1.759115e-01
# max    2.476322e+01  1.669932e+00  1.285989e+00  1.520410e+02  1.499926e+02

# %%
## Plot desnity plot for all features
plt.style.use('seaborn')
pd.DataFrame(X_train_scaled).hist(bins=50,figsize=(20,15),color='orange')
plt.show()

# %%
pd.DataFrame(X_test_scaled).describe()
# Out:
#                  0             1             2             3             4   \
# count  26287.000000  26287.000000  26287.000000  26287.000000  26287.000000
# mean      -0.015316     -0.015316      0.005257      0.002865      0.010193
# std        0.997590      0.997590      0.994449      1.001290      1.005787
# min       -1.726702     -1.726702     -2.506510     -1.072249     -2.856126
# 25%       -0.882204     -0.882204      0.398961     -0.916487     -0.819302
# 50%       -0.020064     -0.020064      0.398961     -0.800288     -0.624045
# 75%        0.842713      0.842713      0.398961      1.079389      0.909266
# max        1.724693      1.724693      0.398961      1.259621      3.391963
#
#                  5             6             7             8             9   \
# count  26287.000000  26287.000000  26287.000000  26287.000000  26287.000000
# mean       0.009864     -0.004539     -0.004529     -0.008789      0.010735
# std        1.000603      0.029237      0.029202      0.992592      1.007675
# min       -4.289752     -0.103437     -0.103444     -2.772013     -2.500542
# 25%       -0.848521     -0.017111     -0.017024     -0.384369     -0.583767
# 50%        0.186968     -0.004799     -0.004754     -0.127212     -0.185680
# 75%        0.780785      0.008063      0.007981      0.317124      0.632413
# max        4.332339      3.020651      3.016727      4.125596      3.915822
#
#                  10            11            12            13            14  \
# count  26287.000000  26287.000000  26287.000000  26287.000000  26287.000000
# mean      -0.003117      0.002799      0.001980      0.010944     -0.010644
# std        0.993652      0.998262      1.007667      1.012158      0.962088
# min       -8.058682     -5.791748     -4.850374     -3.819373     -0.327575
# 25%       -0.212020     -0.323927     -0.221390     -0.190757     -0.325697
# 50%       -0.003083      0.007225     -0.041723     -0.024955     -0.301440
# 75%        0.202908      0.318785      0.181834      0.243802     -0.142274
# max        7.492721      6.538504      4.767298      3.759422     24.328544
#
#                  15            16            17            18            19
# count  26287.000000  26287.000000  26287.000000  26287.000000  26287.000000
# mean      -0.006893     -0.010516     -0.001137      0.001224     -0.006800
# std        0.962490      0.998310      0.999775      0.730914      0.727150
# min       -0.384816     -1.454709     -1.382163     -0.650866     -0.627012
# 25%       -0.382697     -0.939316     -1.081448     -0.459601     -0.460508
# 50%       -0.358987      0.060661      0.022192     -0.195380     -0.238341
# 75%       -0.093255      0.372268      1.100207      0.188425      0.178526
# max       24.346479      1.669932      1.285989     43.269842     40.538979

# %%
plt.subplots(figsize=(30, 18))
plt.subplot(1, 2, 1)
sns.boxplot(data=X_train)
plt.title('X_train Before Scaling')
plt.subplot(1, 2, 2)
sns.boxplot(data=X_train_scaled)
plt.title('X_train After Scaling')
# Out:
# Text(0.5, 1.0, 'X_train After Scaling')

# %% [markdown]
# .

# %% [markdown]
# ‎

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.naive_bayes import BernoulliNB, GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from sklearn.metrics import accuracy_score, classification_report,ConfusionMatrixDisplay, \
                            precision_score, recall_score, f1_score, roc_auc_score,roc_curve

# %%
models={

    "Logisitic Regression":LogisticRegression(),
    "Decision Tree":DecisionTreeClassifier(),
    "Random Forest":RandomForestClassifier(),
    "Gradient Boost":GradientBoostingClassifier(),
    "Adaboost":AdaBoostClassifier(),
    "Xgboost":XGBClassifier(),
    "Gausian":GaussianNB(),
    "Bernoulli":BernoulliNB(),
    "knn"    :KNeighborsClassifier(),
    # "svm"    :SVC() we can't use svm because of high computation
}



for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train_scaled, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(X_train_scaled)
    y_test_pred = model.predict(X_test_scaled)



      # Training set performance
    model_train_accuracy = accuracy_score(y_train, y_train_pred) # Calculate Accuracy
    model_train_f1 = f1_score(y_train, y_train_pred) # Calculate F1-score
    model_train_precision = precision_score(y_train, y_train_pred) # Calculate Precision, add average='weighted'
    model_train_recall = recall_score(y_train, y_train_pred) # Calculate Recall, add average='weighted'
    model_train_rocauc_score = roc_auc_score(y_train, y_train_pred) #Calculate Roc, add multi_class='ovr'


    # Test set performance
    model_test_accuracy = accuracy_score(y_test, y_test_pred) # Calculate Accuracy
    model_test_f1 = f1_score(y_test, y_test_pred) # Calculate F1-score
    model_test_precision = precision_score(y_test, y_test_pred) # Calculate Precision, add average='weighted'
    model_test_recall = recall_score(y_test, y_test_pred) # Calculate Recall, add average='weighted'
    model_test_rocauc_score = roc_auc_score(y_test, y_test_pred) #Calculate Roc, add multi_class='ovr'


    print(list(models.keys())[i])

    print('Model performance for Training set')
    print("- Accuracy: {:.4f}".format(model_train_accuracy))
    print('- F1 score: {:.4f}'.format(model_train_f1))

    print('- Precision: {:.4f}'.format(model_train_precision))
    print('- Recall: {:.4f}'.format(model_train_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_train_rocauc_score))



    print('----------------------------------')

    print('Model performance for Test set')
    print('- Accuracy: {:.4f}'.format(model_test_accuracy))
    print('- F1 score: {:.4f}'.format(model_test_f1))
    print('- Precision: {:.4f}'.format(model_test_precision))
    print('- Recall: {:.4f}'.format(model_test_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_test_rocauc_score))


    print('='*35)
    print('\n')
# Out:
# Logisitic Regression
# Model performance for Training set
# - Accuracy: 0.5832
# - F1 score: 0.0264
# - Precision: 0.4320
# - Recall: 0.0136
# - Roc Auc Score: 0.5005
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.5844
# - F1 score: 0.0290
# - Precision: 0.4780
# - Recall: 0.0149
# - Roc Auc Score: 0.5017
# ===================================
#
#
# Decision Tree
# Model performance for Training set
# - Accuracy: 1.0000
# - F1 score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.6114
# - F1 score: 0.5352
# - Precision: 0.5313
# - Recall: 0.5392
# - Roc Auc Score: 0.6009
# ===================================
#
#
# Random Forest
# Model performance for Training set
# - Accuracy: 1.0000
# - F1 score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.6662
# - F1 score: 0.4809
# - Precision: 0.6780
# - Recall: 0.3725
# - Roc Auc Score: 0.6235
# ===================================
#
#
# Gradient Boost
# Model performance for Training set
# - Accuracy: 0.6408
# - F1 score: 0.2607
# - Precision: 0.8941
# - Recall: 0.1526
# - Roc Auc Score: 0.5699
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.6373
# - F1 score: 0.2540
# - Precision: 0.8679
# - Recall: 0.1488
# - Roc Auc Score: 0.5664
# ===================================
#
#
# Adaboost
# Model performance for Training set
# - Accuracy: 0.6091
# - F1 score: 0.2486
# - Precision: 0.6145
# - Recall: 0.1558
# - Roc Auc Score: 0.5432
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.6060
# - F1 score: 0.2391
# - Precision: 0.6024
# - Recall: 0.1491
# - Roc Auc Score: 0.5397
# ===================================
#
#
# Xgboost
# Model performance for Training set
# - Accuracy: 0.7625
# - F1 score: 0.6322
# - Precision: 0.8848
# - Recall: 0.4918
# - Roc Auc Score: 0.7232
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.6513
# - F1 score: 0.4478
# - Precision: 0.6530
# - Recall: 0.3407
# - Roc Auc Score: 0.6061
# ===================================
#
#
# Gausian
# Model performance for Training set
# - Accuracy: 0.4238
# - F1 score: 0.5897
# - Precision: 0.4185
# - Recall: 0.9976
# - Roc Auc Score: 0.5072
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.4233
# - F1 score: 0.5894
# - Precision: 0.4183
# - Recall: 0.9974
# - Roc Auc Score: 0.5067
# ===================================
#
#
# Bernoulli
# Model performance for Training set
# - Accuracy: 0.5825
# - F1 score: 0.0797
# - Precision: 0.4685
# - Recall: 0.0435
# - Roc Auc Score: 0.5042
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.5834
# - F1 score: 0.0758
# - Precision: 0.4782
# - Recall: 0.0412
# - Roc Auc Score: 0.5046
# ===================================
#
#
# knn
# Model performance for Training set
# - Accuracy: 0.7283
# - F1 score: 0.6379
# - Precision: 0.7137
# - Recall: 0.5766
# - Roc Auc Score: 0.7063
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.5775
# - F1 score: 0.4342
# - Precision: 0.4887
# - Recall: 0.3907
# - Roc Auc Score: 0.5504
# ===================================

# %%
## Hyperparameter Training
rf_params = {"max_depth": [5, 8, 15, None, 10],
             "max_features": [5, 7, "auto", 8],
             "min_samples_split": [2, 8, 15, 20],
             "n_estimators": [100, 200, 500, 1000]}

# adaboost_param={
#     "n_estimators":[50,60,70,80,90],
#     "algorithm":['SAMME','SAMME.R']
# }

# xgboost_params = {"learning_rate": [0.1, 0.01],
#                   "max_depth": [5, 8, 12, 20, 30],
#                   "n_estimators": [100, 200, 300],
#                   "colsample_bytree": [0.5, 0.8, 1, 0.3, 0.4]}

# gradient_params={"loss": ['log_loss','deviance','exponential'],
#              "criterion": ['friedman_mse','squared_error','mse'],
#              "min_samples_split": [2, 8, 15, 20],
#              "n_estimators": [100, 200, 500],
#               "max_depth": [5, 8, 15, None, 10]
#                 }

# %%
rf_params
# Out:
# {'max_depth': [5, 8, 15, None, 10],
#  'max_features': [5, 7, 'auto', 8],
#  'min_samples_split': [2, 8, 15, 20],
#  'n_estimators': [100, 200, 500, 1000]}

# %%
# Models list for Hyperparameter tuning
randomcv_models = [
                   ("RF", RandomForestClassifier(), rf_params)

                   ]

# %%
randomcv_models
# Out:
# [('RF',
#   RandomForestClassifier(),
#   {'max_depth': [5, 8, 15, None, 10],
#    'max_features': [5, 7, 'auto', 8],
#    'min_samples_split': [2, 8, 15, 20],
#    'n_estimators': [100, 200, 500, 1000]})]

# %%
from sklearn.model_selection import RandomizedSearchCV

model_param = {}
for name, model, params in randomcv_models:
    random = RandomizedSearchCV(estimator=model,
                                   param_distributions=params,
                                   n_iter=100,
                                   cv=3,
                                   verbose=2,
                                   n_jobs=-1)
    random.fit(X_train, y_train)
    model_param[name] = random.best_params_

for model_name in model_param:
    print(f"---------------- Best Params for {model_name} -------------------")
    print(model_param[model_name])
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-6c5229b313bb> in <cell line: 4>()
#       9                                    verbose=2,
#      10                                    n_jobs=-1)
# ---> 11     random.fit(X_train, y_train)
#      12     model_param[name] = random.best_params_
#      13
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     896                 return results
#     897
# --> 898             self._run_search(evaluate_candidates)
#     899
#     900             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1807     def _run_search(self, evaluate_candidates):
#    1808         """Search n_iter candidates from param_distributions"""
# -> 1809         evaluate_candidates(
#    1810             ParameterSampler(
#    1811                 self.param_distributions, self.n_iter, random_state=self.random_state
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     843                     )
#     844
# --> 845                 out = parallel(
#     846                     delayed(_fit_and_score)(
#     847                         clone(base_estimator),
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      63             for delayed_func, args, kwargs in iterable
#      64         )
# ---> 65         return super().__call__(iterable_with_config)
#      66
#      67
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    2005         next(output)
#    2006
# -> 2007         return output if self.return_generator else list(output)
#    2008
#    2009     def __repr__(self):
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _get_outputs(self, iterator, pre_dispatch)
#    1648
#    1649             with self._backend.retrieval_context():
# -> 1650                 yield from self._retrieve()
#    1651
#    1652         except GeneratorExit:
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _retrieve(self)
#    1760                 (self._jobs[0].get_status(
#    1761                     timeout=self.timeout) == TASK_PENDING)):
# -> 1762                 time.sleep(0.01)
#    1763                 continue
#    1764
#
# KeyboardInterrupt:

# %%
models={

    "Random Forest":RandomForestClassifier(n_estimators=200,min_samples_split=2,
                                          max_features='auto',max_depth=None)
}
for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Training set performance
    model_train_accuracy = accuracy_score(y_train, y_train_pred) # Calculate Accuracy
    model_train_f1 = f1_score(y_train, y_train_pred, average='weighted') # Calculate F1-score
    model_train_precision = precision_score(y_train, y_train_pred) # Calculate Precision
    model_train_recall = recall_score(y_train, y_train_pred) # Calculate Recall
    model_train_rocauc_score = roc_auc_score(y_train, y_train_pred)


    # Test set performance
    model_test_accuracy = accuracy_score(y_test, y_test_pred) # Calculate Accuracy
    model_test_f1 = f1_score(y_test, y_test_pred, average='weighted') # Calculate F1-score
    model_test_precision = precision_score(y_test, y_test_pred) # Calculate Precision
    model_test_recall = recall_score(y_test, y_test_pred) # Calculate Recall
    model_test_rocauc_score = roc_auc_score(y_test, y_test_pred) #Calculate Roc


    print(list(models.keys())[i])

    print('Model performance for Training set')
    print("- Accuracy: {:.4f}".format(model_train_accuracy))
    print('- F1 score: {:.4f}'.format(model_train_f1))

    print('- Precision: {:.4f}'.format(model_train_precision))
    print('- Recall: {:.4f}'.format(model_train_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_train_rocauc_score))



    print('----------------------------------')

    print('Model performance for Test set')
    print('- Accuracy: {:.4f}'.format(model_test_accuracy))
    print('- F1 score: {:.4f}'.format(model_test_f1))
    print('- Precision: {:.4f}'.format(model_test_precision))
    print('- Recall: {:.4f}'.format(model_test_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_test_rocauc_score))


    print('='*35)
    print('\n')
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# <ipython-input-85-148c46894e7a> in <cell line: 6>()
#       6 for i in range(len(list(models))):
#       7     model = list(models.values())[i]
# ----> 8     model.fit(X_train, y_train) # Train model
#       9
#      10     # Make predictions
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1143
#    1144             if not global_skip_validation and not partial_fit_and_fitted:
# -> 1145                 estimator._validate_params()
#    1146
#    1147             with config_context(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_params(self)
#     636         accepted constraints.
#     637         """
# --> 638         validate_parameter_constraints(
#     639             self._parameter_constraints,
#     640             self.get_params(deep=False),
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      94                 )
#      95
# ---> 96             raise InvalidParameterError(
#      97                 f"The {param_name!r} parameter of {caller_name} must be"
#      98                 f" {constraints_str}. Got {param_val!r} instead."
#
# InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.

# %%
## Plot ROC AUC Curve
from sklearn.metrics import roc_auc_score,roc_curve
plt.figure()

# Add the models to the list that you want to view on the ROC plot
auc_models = [
{
    'label': 'Random Forest Classifier',
    'model': RandomForestClassifier(n_estimators=1000,min_samples_split=2,
                                          max_features=7,max_depth=None),
    'auc':  0.8325
},

]
# create loop through all model
for algo in auc_models:
    model = algo['model'] # select the model
    model.fit(X_train, y_train) # train the model
# Compute False postive rate, and True positive rate
    fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:,1])
# Calculate Area under the curve to display on the plot
    plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % (algo['label'], algo['auc']))
# Custom settings for the plot
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('1-Specificity(False Positive Rate)')
plt.ylabel('Sensitivity(True Positive Rate)')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.savefig("auc.png")
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Initialize and train the RandomForest model
model = RandomForestClassifier(random_state=42)
model.fit(X_train_scaled, y_train)

# Make predictions and evaluate accuracy
y_pred = model.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_pred)

print(f"Model Accuracy: {accuracy}")
# Out:
# Model Accuracy: 0.5238888888888888

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, 30],
    'max_features': ['auto', 'sqrt'],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

rf = RandomForestClassifier(random_state=42)
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
grid_search.fit(X_train_scaled, y_train)

best_model = grid_search.best_estimator_
y_pred_best = best_model.predict(X_test_scaled)
best_accuracy = accuracy_score(y_test, y_pred_best)

print(f"Best Model Accuracy: {best_accuracy}")
print(f"Best Parameters: {grid_search.best_params()}")
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 243 fits failed out of a total of 486.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 162 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 81 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:979: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.54523503 0.54867256 0.54914144
#  0.54836016 0.54882856 0.54726635 0.54937534 0.54867247 0.54828209
#  0.54695371 0.5487507  0.54890717 0.54812547 0.54679741 0.54906306
#  0.54804757 0.55062575 0.54976637 0.548282   0.55015698 0.54875086
#  0.548282   0.55015698 0.54875086 0.54625058 0.54890684 0.55156325
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.53531274 0.53398513 0.53484467
#  0.53562549 0.53757896 0.53617262 0.53757887 0.53867263 0.53929778
#  0.5361726  0.53961016 0.54031354 0.53546902 0.53601651 0.53875078
#  0.53562548 0.53812557 0.53945402 0.54007886 0.54218781 0.53851622
#  0.54007886 0.54218781 0.53851622 0.53796939 0.53875076 0.54015709
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.52765698 0.52765715 0.52945388
#  0.52414147 0.53179793 0.53117275 0.53679752 0.53281287 0.53054746
#  0.52968743 0.53453157 0.53500069 0.53507866 0.53812581 0.53648499
#  0.53398524 0.53554769 0.53289155 0.53492241 0.53679752 0.53695346
#  0.53492241 0.53679752 0.53695346 0.53492248 0.53679746 0.53609461]
#   warnings.warn(
# Best Model Accuracy: 0.5473611111111111
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-132-6934866589f2> in <cell line: 20>()
#      18
#      19 print(f"Best Model Accuracy: {best_accuracy}")
# ---> 20 print(f"Best Parameters: {grid_search.best_params()}")
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params'

# %% [markdown]
# **K nearest neighbour**

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
classifier=KNeighborsClassifier(n_neighbors=30,algorithm='ball_tree')
classifier.fit(X_train_scaled,y_train)
# Out:
# KNeighborsClassifier(algorithm='ball_tree', n_neighbors=30)

# %%
y_pred_knn=classifier.predict(X_test_scaled)

# %%
score=accuracy_score(y_pred_knn,y_test)
print("KNN")
print(score)
print(classification_report(y_pred_knn,y_test))
print(confusion_matrix(y_pred_knn,y_test))
# Out:
# KNN
# 0.544
#               precision    recall  f1-score   support
#
#            0       0.77      0.56      0.65     13475
#            1       0.27      0.49      0.35      4525
#
#     accuracy                           0.54     18000
#    macro avg       0.52      0.52      0.50     18000
# weighted avg       0.64      0.54      0.57     18000
#
# [[7594 5881]
#  [2327 2198]]

# %% [markdown]
# **Naive bayes**

# %%
from sklearn.naive_bayes import GaussianNB

gnb=GaussianNB()
gnb.fit(X_train_scaled,y_train)
# Out:
# GaussianNB()

# %%
y_pred_g=gnb.predict(X_test_scaled)

# %%
score=accuracy_score(y_pred_g,y_test)
print("Naive bayes")
print(score)
print(classification_report(y_pred_g,y_test))
print(confusion_matrix(y_pred_g,y_test))
# Out:
# Naive bayes
# 0.4568888888888889
#               precision    recall  f1-score   support
#
#            0       0.09      0.55      0.15      1589
#            1       0.91      0.45      0.60     16411
#
#     accuracy                           0.46     18000
#    macro avg       0.50      0.50      0.38     18000
# weighted avg       0.84      0.46      0.56     18000
#
# [[ 867  722]
#  [9054 7357]]

# %% [markdown]
# SVC

# %%
from sklearn.svm import SVC

svc=SVC(kernel='linear')
svc.fit(X_train_scaled,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred1=svc.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
score=accuracy_score(y_pred1,y_test)
print("SVC")
print(score)
print(classification_report(y_pred1,y_test))
print(confusion_matrix(y_pred1,y_test))
# Out:
# SVC
# 0.5511666666666667
#               precision    recall  f1-score   support
#
#            0       1.00      0.55      0.71     18000
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.55     18000
#    macro avg       0.50      0.28      0.36     18000
# weighted avg       1.00      0.55      0.71     18000
#
# [[9921 8079]
#  [   0    0]]

# %% [markdown]
# rbf krrnal

# %%
rbf=SVC(kernel='rbf')
rbf.fit(X_train_scaled,y_train)
# Out:
# SVC()

# %%
y_pred2=svc.predict(X_test_scaled)

# %%
print(classification_report(y_pred2,y_test))
print(confusion_matrix(y_pred2,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.55      0.71     18000
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.55     18000
#    macro avg       0.50      0.28      0.36     18000
# weighted avg       1.00      0.55      0.71     18000
#
# [[9921 8079]
#  [   0    0]]

# %% [markdown]
# Polynomial kernal

# %%
polynomial=SVC(kernel='poly')
polynomial.fit(X_train_scaled,y_train)
# Out:
# SVC(kernel='poly')

# %%
## Prediction
y_pred3=polynomial.predict(X_test_scaled)

# %%
print(classification_report(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.98      0.71      9921
#            1       0.43      0.02      0.03      8079
#
#     accuracy                           0.55     18000
#    macro avg       0.49      0.50      0.37     18000
# weighted avg       0.50      0.55      0.40     18000
#
# [[9725  196]
#  [7932  147]]

# %% [markdown]
# Sigmoid

# %%
sigmoid=SVC(kernel='sigmoid')
sigmoid.fit(X_train_scaled,y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
## Prediction
y_pred3=sigmoid.predict(X_test_scaled)

# %%
print(classification_report(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.55      0.55      9921
#            1       0.45      0.45      0.45      8079
#
#     accuracy                           0.51     18000
#    macro avg       0.50      0.50      0.50     18000
# weighted avg       0.51      0.51      0.51     18000
#
# [[5493 4428]
#  [4431 3648]]

# %% [markdown]
# Hyperparameter tuning svm

# %%
from sklearn.model_selection import GridSearchCV

# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']}

# %%
grid=GridSearchCV(SVC(),param_grid=param_grid,refit=True,cv=2,verbose=3)

# %%
# randomcv=RandomizedSearchCV(SVC(),param_grid=param_grid,refit=True,cv=2,verbose=3)
randomcv=RandomizedSearchCV(estimator=SVC(),param_distributions=param_grid,cv=2)

# %%
randomcv.fit(X_train_scaled,y_train)
# Out:
# RandomizedSearchCV(cv=2, estimator=SVC(),
#                    param_distributions={'C': [0.1, 1, 10, 100, 1000],
#                                         'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                                         'kernel': ['rbf']})

# %%
## Prediction
y_pred4=randomcv.predict(X_test_scaled)
print(classification_report(y_test,y_pred4))
print(confusion_matrix(y_test,y_pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      1.00      0.71      9921
#            1       0.00      0.00      0.00      8079
#
#     accuracy                           0.55     18000
#    macro avg       0.28      0.50      0.36     18000
# weighted avg       0.30      0.55      0.39     18000
#
# [[9921    0]
#  [8079    0]]

# %%
grid.fit(X_train_scaled,y_train)
# Out:
# Fitting 2 folds for each of 25 candidates, totalling 50 fits
# [CV 1/2] END ........C=0.1, gamma=1, kernel=rbf;, score=0.551 total time=  54.3s
# [CV 2/2] END ........C=0.1, gamma=1, kernel=rbf;, score=0.547 total time=  54.6s
# [CV 1/2] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.551 total time=  43.4s
# [CV 2/2] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.551 total time=  43.6s
# [CV 1/2] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.551 total time=  42.3s
# [CV 2/2] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.551 total time=  42.6s
# [CV 1/2] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.551 total time=  39.8s
# [CV 2/2] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.551 total time=  40.3s
# [CV 1/2] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.551 total time=  39.4s
# [CV 2/2] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.551 total time=  39.4s
# [CV 1/2] END ..........C=1, gamma=1, kernel=rbf;, score=0.539 total time= 1.2min
# [CV 2/2] END ..........C=1, gamma=1, kernel=rbf;, score=0.534 total time= 1.1min
# [CV 1/2] END ........C=1, gamma=0.1, kernel=rbf;, score=0.545 total time=  43.9s
# [CV 2/2] END ........C=1, gamma=0.1, kernel=rbf;, score=0.549 total time=  44.0s
# [CV 1/2] END .......C=1, gamma=0.01, kernel=rbf;, score=0.551 total time=  44.7s
# [CV 2/2] END .......C=1, gamma=0.01, kernel=rbf;, score=0.551 total time=  44.4s
# [CV 1/2] END ......C=1, gamma=0.001, kernel=rbf;, score=0.551 total time=  42.0s
# [CV 2/2] END ......C=1, gamma=0.001, kernel=rbf;, score=0.551 total time=  42.1s
# [CV 1/2] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.551 total time=  40.0s
# [CV 2/2] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.551 total time=  39.9s
# [CV 1/2] END .........C=10, gamma=1, kernel=rbf;, score=0.525 total time= 2.1min
# [CV 2/2] END .........C=10, gamma=1, kernel=rbf;, score=0.525 total time= 2.0min
# [CV 1/2] END .......C=10, gamma=0.1, kernel=rbf;, score=0.534 total time= 1.1min
# [CV 2/2] END .......C=10, gamma=0.1, kernel=rbf;, score=0.532 total time= 1.1min
# [CV 1/2] END ......C=10, gamma=0.01, kernel=rbf;, score=0.550 total time=  46.8s
# [CV 2/2] END ......C=10, gamma=0.01, kernel=rbf;, score=0.550 total time=  46.9s
# [CV 1/2] END .....C=10, gamma=0.001, kernel=rbf;, score=0.551 total time=  48.6s
# [CV 2/2] END .....C=10, gamma=0.001, kernel=rbf;, score=0.551 total time=  48.3s
# [CV 1/2] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.551 total time=  41.9s
# [CV 2/2] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.551 total time=  42.6s
# [CV 1/2] END ........C=100, gamma=1, kernel=rbf;, score=0.521 total time= 3.3min
# [CV 2/2] END ........C=100, gamma=1, kernel=rbf;, score=0.523 total time= 3.3min
# [CV 1/2] END ......C=100, gamma=0.1, kernel=rbf;, score=0.527 total time= 2.8min
# [CV 2/2] END ......C=100, gamma=0.1, kernel=rbf;, score=0.525 total time= 2.7min
# [CV 1/2] END .....C=100, gamma=0.01, kernel=rbf;, score=0.547 total time= 1.1min
# [CV 2/2] END .....C=100, gamma=0.01, kernel=rbf;, score=0.547 total time= 1.1min
# [CV 1/2] END ....C=100, gamma=0.001, kernel=rbf;, score=0.551 total time= 1.1min
# [CV 2/2] END ....C=100, gamma=0.001, kernel=rbf;, score=0.551 total time= 1.1min
# [CV 1/2] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.551 total time=  51.9s
# [CV 2/2] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.551 total time=  52.3s
# [CV 1/2] END .......C=1000, gamma=1, kernel=rbf;, score=0.520 total time= 4.8min
# [CV 2/2] END .......C=1000, gamma=1, kernel=rbf;, score=0.520 total time= 4.6min
# [CV 1/2] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.519 total time=12.5min
# [CV 2/2] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.517 total time=13.4min
# [CV 1/2] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.542 total time= 3.9min
# [CV 2/2] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.551 total time= 3.8min
# [CV 1/2] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.551 total time= 1.9min
# [CV 2/2] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.551 total time= 1.7min
# [CV 1/2] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.551 total time= 1.1min
# [CV 2/2] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.551 total time= 1.1min
# GridSearchCV(cv=2, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
## Prediction
y_pred5=grid.predict(X_test_scaled)
print(classification_report(y_test,y_pred5))
print(confusion_matrix(y_test,y_pred5))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      1.00      0.71      9921
#            1       0.00      0.00      0.00      8079
#
#     accuracy                           0.55     18000
#    macro avg       0.28      0.50      0.36     18000
# weighted avg       0.30      0.55      0.39     18000
#
# [[9921    0]
#  [8079    0]]
