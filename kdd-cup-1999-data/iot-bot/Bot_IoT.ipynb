# %%
# Out:
# /kaggle/input/bot-iot/data_26.csv
# /kaggle/input/bot-iot/data_33.csv
# /kaggle/input/bot-iot/data_49.csv
# /kaggle/input/bot-iot/data_44.csv
# /kaggle/input/bot-iot/data_38.csv
# /kaggle/input/bot-iot/data_22.csv
# /kaggle/input/bot-iot/data_30.csv
# /kaggle/input/bot-iot/data_57.csv
# /kaggle/input/bot-iot/data_46.csv
# /kaggle/input/bot-iot/data_58.csv
# /kaggle/input/bot-iot/data_21.csv
# /kaggle/input/bot-iot/data_59.csv
# /kaggle/input/bot-iot/data_32.csv
# /kaggle/input/bot-iot/data_69.csv
# /kaggle/input/bot-iot/data_19.csv
# /kaggle/input/bot-iot/data_47.csv
# /kaggle/input/bot-iot/data_14.csv
# /kaggle/input/bot-iot/data_9.csv
# /kaggle/input/bot-iot/data_52.csv
# /kaggle/input/bot-iot/data_18.csv
# /kaggle/input/bot-iot/data_53.csv
# /kaggle/input/bot-iot/data_73.csv
# /kaggle/input/bot-iot/data_63.csv
# /kaggle/input/bot-iot/data_70.csv
# /kaggle/input/bot-iot/data_17.csv
# /kaggle/input/bot-iot/data_7.csv
# /kaggle/input/bot-iot/data_67.csv
# /kaggle/input/bot-iot/data_names.csv
# /kaggle/input/bot-iot/data_11.csv
# /kaggle/input/bot-iot/data_36.csv
# /kaggle/input/bot-iot/data_37.csv
# /kaggle/input/bot-iot/data_40.csv
# /kaggle/input/bot-iot/data_66.csv
# /kaggle/input/bot-iot/data_24.csv
# /kaggle/input/bot-iot/data_16.csv
# /kaggle/input/bot-iot/data_28.csv
# /kaggle/input/bot-iot/data_20.csv
# /kaggle/input/bot-iot/data_72.csv
# /kaggle/input/bot-iot/data_31.csv
# /kaggle/input/bot-iot/data_74.csv
# /kaggle/input/bot-iot/data_10.csv
# /kaggle/input/bot-iot/data_6.csv
# /kaggle/input/bot-iot/data_1.csv
# /kaggle/input/bot-iot/data_48.csv
# /kaggle/input/bot-iot/data_56.csv
# /kaggle/input/bot-iot/data_34.csv
# /kaggle/input/bot-iot/data_4.csv
# /kaggle/input/bot-iot/data_60.csv
# /kaggle/input/bot-iot/data_43.csv
# /kaggle/input/bot-iot/data_65.csv
# /kaggle/input/bot-iot/data_2.csv
# /kaggle/input/bot-iot/data_42.csv
# /kaggle/input/bot-iot/data_51.csv
# /kaggle/input/bot-iot/data_12.csv
# /kaggle/input/bot-iot/data_45.csv
# /kaggle/input/bot-iot/data_25.csv
# /kaggle/input/bot-iot/data_64.csv
# /kaggle/input/bot-iot/data_62.csv
# /kaggle/input/bot-iot/data_27.csv
# /kaggle/input/bot-iot/data_71.csv
# /kaggle/input/bot-iot/data_8.csv
# /kaggle/input/bot-iot/data_39.csv
# /kaggle/input/bot-iot/data_23.csv
# /kaggle/input/bot-iot/data_35.csv
# /kaggle/input/bot-iot/data_54.csv
# /kaggle/input/bot-iot/data_41.csv
# /kaggle/input/bot-iot/data_50.csv
# /kaggle/input/bot-iot/data_5.csv
# /kaggle/input/bot-iot/data_13.csv
# /kaggle/input/bot-iot/data_68.csv
# /kaggle/input/bot-iot/data_3.csv
# /kaggle/input/bot-iot/data_55.csv
# /kaggle/input/bot-iot/data_15.csv
# /kaggle/input/bot-iot/data_61.csv
# /kaggle/input/bot-iot/data_29.csv

# %%
df=pd.read_csv("/kaggle/input/bot-iot/data_1.csv")
# Out:
# /tmp/ipykernel_185/1882835921.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/kaggle/input/bot-iot/data_1.csv")

# %%
pd.read_csv("/kaggle/input/bot-iot/data_1.csv")
# Out:
# /tmp/ipykernel_29/2779279090.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("/kaggle/input/bot-iot/data_1.csv")
#         pkSeqID         stime flgs proto            saddr  sport  \
# 0             1  1.526344e+09    e   arp    192.168.100.1    NaN
# 1             2  1.526344e+09    e   tcp    192.168.100.7    139
# 2             3  1.526344e+09    e   udp  192.168.100.149  51838
# 3             4  1.526344e+09    e   arp    192.168.100.4    NaN
# 4             5  1.526344e+09    e   udp   192.168.100.27  58999
# ...         ...           ...  ...   ...              ...    ...
# 999995   999996  1.526949e+09    e   tcp  192.168.100.150  49731
# 999996   999997  1.526949e+09    e   tcp  192.168.100.150  49731
# 999997   999998  1.526949e+09    e   tcp  192.168.100.150  49731
# 999998   999999  1.526949e+09    e   tcp  192.168.100.150  49731
# 999999  1000000  1.526949e+09    e   tcp  192.168.100.150  49731
#
#                  daddr  dport  pkts  bytes  ... spkts  dpkts  sbytes  dbytes  \
# 0        192.168.100.3    NaN     4    240  ...     2      2     120     120
# 1        192.168.100.4  36390    10    680  ...     5      5     350     330
# 2       27.124.125.250    123     2    180  ...     1      1      90      90
# 3        192.168.100.7    NaN    10    510  ...     5      5     210     300
# 4        192.168.100.1     53     4    630  ...     2      2     174     456
# ...                ...    ...   ...    ...  ...   ...    ...     ...     ...
# 999995   192.168.100.3  12020     2    120  ...     1      1      60      60
# 999996   192.168.100.3  60532     2    120  ...     1      1      60      60
# 999997   192.168.100.3  52144     2    120  ...     1      1      60      60
# 999998   192.168.100.3  58105     2    120  ...     1      1      60      60
# 999999   192.168.100.3  16416     2    120  ...     1      1      60      60
#
#              rate     srate     drate  attack        category  subcategory
# 0        0.002508  0.000836  0.000836       0          Normal        Normal
# 1        0.006190  0.002751  0.002751       0          Normal        Normal
# 2       20.590960  0.000000  0.000000       0          Normal        Normal
# 3        0.006189  0.002751  0.002751       0          Normal        Normal
# 4        0.005264  0.001755  0.001755       0          Normal        Normal
# ...           ...       ...       ...     ...             ...           ...
# 999995  23.854963  0.000000  0.000000       1  Reconnaissance  Service_Scan
# 999996  23.854963  0.000000  0.000000       1  Reconnaissance  Service_Scan
# 999997  23.862362  0.000000  0.000000       1  Reconnaissance  Service_Scan
# 999998  23.854963  0.000000  0.000000       1  Reconnaissance  Service_Scan
# 999999  23.854393  0.000000  0.000000       1  Reconnaissance  Service_Scan
#
# [1000000 rows x 35 columns]

# %%
import pandas as pd
import os

# List of file paths
file_paths = [
    '/kaggle/input/bot-iot/data_26.csv',
    '/kaggle/input/bot-iot/data_33.csv',
    '/kaggle/input/bot-iot/data_49.csv',
    '/kaggle/input/bot-iot/data_44.csv',
    '/kaggle/input/bot-iot/data_38.csv',
    '/kaggle/input/bot-iot/data_22.csv',
    '/kaggle/input/bot-iot/data_30.csv',
    '/kaggle/input/bot-iot/data_57.csv',
    '/kaggle/input/bot-iot/data_46.csv',
    '/kaggle/input/bot-iot/data_58.csv',
    '/kaggle/input/bot-iot/data_21.csv',
    '/kaggle/input/bot-iot/data_59.csv',
    '/kaggle/input/bot-iot/data_32.csv',
    '/kaggle/input/bot-iot/data_69.csv',
    '/kaggle/input/bot-iot/data_19.csv',
    '/kaggle/input/bot-iot/data_47.csv',
    '/kaggle/input/bot-iot/data_14.csv',
    '/kaggle/input/bot-iot/data_9.csv',
    '/kaggle/input/bot-iot/data_52.csv',
    '/kaggle/input/bot-iot/data_18.csv',
    '/kaggle/input/bot-iot/data_53.csv',
    '/kaggle/input/bot-iot/data_73.csv',
    '/kaggle/input/bot-iot/data_63.csv',
    '/kaggle/input/bot-iot/data_70.csv',
    '/kaggle/input/bot-iot/data_17.csv',
    '/kaggle/input/bot-iot/data_7.csv',
    '/kaggle/input/bot-iot/data_67.csv',
#     '/kaggle/input/bot-iot/data_names.csv',

]

# Load and merge all CSV files
dfs = [pd.read_csv(file) for file in file_paths]
merged_df = pd.concat(dfs, ignore_index=True)

# Display the first few rows of the merged DataFrame
print(merged_df.head())
# Out:
# /tmp/ipykernel_185/1151320406.py:38: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_185/1151320406.py:38: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_185/1151320406.py:38: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_185/1151320406.py:38: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_185/1151320406.py:38: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_185/1151320406.py:38: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_185/1151320406.py:38: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_185/1151320406.py:38: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_185/1151320406.py:38: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_185/1151320406.py:38: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_185/1151320406.py:38: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_185/1151320406.py:38: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_185/1151320406.py:38: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_185/1151320406.py:38: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_185/1151320406.py:38: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_185/1151320406.py:38: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_185/1151320406.py:38: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
#     pkSeqID         stime flgs proto            saddr   sport          daddr  \
# 0  25000001  1.528086e+09    e   udp  192.168.100.148  8073.0  192.168.100.7
# 1  25000002  1.528086e+09    e   udp  192.168.100.148  8074.0  192.168.100.7
# 2  25000003  1.528086e+09    e   udp  192.168.100.148  8075.0  192.168.100.7
# 3  25000004  1.528086e+09    e   udp  192.168.100.148  8076.0  192.168.100.7
# 4  25000005  1.528086e+09    e   udp  192.168.100.148  8077.0  192.168.100.7
#
#   dport  pkts  bytes  ... spkts  dpkts  sbytes  dbytes      rate     srate  \
# 0  80.0     2    120  ...     2      0     120       0  0.210891  0.210891
# 1  80.0     2    120  ...     2      0     120       0  0.210891  0.210891
# 2  80.0     2    120  ...     2      0     120       0  0.210891  0.210891
# 3  80.0     2    120  ...     2      0     120       0  0.210891  0.210891
# 4  80.0     2    120  ...     2      0     120       0  0.210891  0.210891
#
#    drate  attack  category  subcategory
# 0    0.0       1       DoS           UDP
# 1    0.0       1       DoS           UDP
# 2    0.0       1       DoS           UDP
# 3    0.0       1       DoS           UDP
# 4    0.0       1       DoS           UDP
#
# [5 rows x 35 columns]

# %%
merged_df.to_csv("bot-iot-26-67")

# %%
merged_df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 merged_df.info()
#
# NameError: name 'merged_df' is not defined

# %%
import pandas as pd
import os

# List of file paths
file_paths = [
#     '/kaggle/input/bot-iot/data_names.csv',
    '/kaggle/input/bot-iot/data_11.csv',
    '/kaggle/input/bot-iot/data_36.csv',
    '/kaggle/input/bot-iot/data_37.csv',
    '/kaggle/input/bot-iot/data_40.csv',
    '/kaggle/input/bot-iot/data_66.csv',
    '/kaggle/input/bot-iot/data_24.csv',
    '/kaggle/input/bot-iot/data_16.csv',
    '/kaggle/input/bot-iot/data_28.csv',
    '/kaggle/input/bot-iot/data_20.csv',
    '/kaggle/input/bot-iot/data_72.csv',
    '/kaggle/input/bot-iot/data_31.csv',
    '/kaggle/input/bot-iot/data_74.csv',
    '/kaggle/input/bot-iot/data_10.csv',
    '/kaggle/input/bot-iot/data_6.csv',
    '/kaggle/input/bot-iot/data_1.csv',
    '/kaggle/input/bot-iot/data_48.csv',
    '/kaggle/input/bot-iot/data_56.csv',
    '/kaggle/input/bot-iot/data_34.csv',
    '/kaggle/input/bot-iot/data_4.csv',
    '/kaggle/input/bot-iot/data_60.csv',
    '/kaggle/input/bot-iot/data_43.csv',
    '/kaggle/input/bot-iot/data_65.csv',
    '/kaggle/input/bot-iot/data_2.csv',
    '/kaggle/input/bot-iot/data_42.csv',
    '/kaggle/input/bot-iot/data_51.csv',
    '/kaggle/input/bot-iot/data_12.csv',
    '/kaggle/input/bot-iot/data_45.csv',
    '/kaggle/input/bot-iot/data_25.csv',
    '/kaggle/input/bot-iot/data_64.csv',
    '/kaggle/input/bot-iot/data_62.csv',
    '/kaggle/input/bot-iot/data_27.csv',
    '/kaggle/input/bot-iot/data_71.csv',
    '/kaggle/input/bot-iot/data_8.csv',
    '/kaggle/input/bot-iot/data_39.csv',
    '/kaggle/input/bot-iot/data_23.csv',
    '/kaggle/input/bot-iot/data_35.csv',
    '/kaggle/input/bot-iot/data_54.csv',
    '/kaggle/input/bot-iot/data_41.csv',
    '/kaggle/input/bot-iot/data_50.csv',
    '/kaggle/input/bot-iot/data_5.csv',
    '/kaggle/input/bot-iot/data_13.csv',
    '/kaggle/input/bot-iot/data_68.csv',
    '/kaggle/input/bot-iot/data_3.csv',
    '/kaggle/input/bot-iot/data_55.csv',
    '/kaggle/input/bot-iot/data_15.csv',
    '/kaggle/input/bot-iot/data_61.csv',
    '/kaggle/input/bot-iot/data_29.csv'
]

# Load and merge all CSV files
dfs = [pd.read_csv(file) for file in file_paths]
merged_df2 = pd.concat(dfs, ignore_index=True)

# Display the first few rows of the merged DataFrame
print(merged_df2.head())
# Out:
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]
# /tmp/ipykernel_125/1980004092.py:57: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(file) for file in file_paths]

# %%
df.head()
# Out:
#    pkSeqID         stime flgs proto            saddr  sport           daddr  \
# 0        1  1.526344e+09    e   arp    192.168.100.1    NaN   192.168.100.3
# 1        2  1.526344e+09    e   tcp    192.168.100.7    139   192.168.100.4
# 2        3  1.526344e+09    e   udp  192.168.100.149  51838  27.124.125.250
# 3        4  1.526344e+09    e   arp    192.168.100.4    NaN   192.168.100.7
# 4        5  1.526344e+09    e   udp   192.168.100.27  58999   192.168.100.1
#
#    dport  pkts  bytes  ... spkts  dpkts  sbytes  dbytes       rate     srate  \
# 0    NaN     4    240  ...     2      2     120     120   0.002508  0.000836
# 1  36390    10    680  ...     5      5     350     330   0.006190  0.002751
# 2    123     2    180  ...     1      1      90      90  20.590960  0.000000
# 3    NaN    10    510  ...     5      5     210     300   0.006189  0.002751
# 4     53     4    630  ...     2      2     174     456   0.005264  0.001755
#
#       drate  attack  category  subcategory
# 0  0.000836       0    Normal        Normal
# 1  0.002751       0    Normal        Normal
# 2  0.000000       0    Normal        Normal
# 3  0.002751       0    Normal        Normal
# 4  0.001755       0    Normal        Normal
#
# [5 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 35 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   pkSeqID       1000000 non-null  int64
#  1   stime         1000000 non-null  float64
#  2   flgs          1000000 non-null  object
#  3   proto         1000000 non-null  object
#  4   saddr         1000000 non-null  object
#  5   sport         999513 non-null   object
#  6   daddr         1000000 non-null  object
#  7   dport         999513 non-null   object
#  8   pkts          1000000 non-null  int64
#  9   bytes         1000000 non-null  int64
#  10  state         1000000 non-null  object
#  11  ltime         1000000 non-null  float64
#  12  seq           1000000 non-null  int64
#  13  dur           1000000 non-null  float64
#  14  mean          1000000 non-null  float64
#  15  stddev        1000000 non-null  float64
#  16  smac          0 non-null        float64
#  17  dmac          0 non-null        float64
#  18  sum           1000000 non-null  float64
#  19  min           1000000 non-null  float64
#  20  max           1000000 non-null  float64
#  21  soui          0 non-null        float64
#  22  doui          0 non-null        float64
#  23  sco           0 non-null        float64
#  24  dco           0 non-null        float64
#  25  spkts         1000000 non-null  int64
#  26  dpkts         1000000 non-null  int64
#  27  sbytes        1000000 non-null  int64
#  28  dbytes        1000000 non-null  int64
#  29  rate          1000000 non-null  float64
#  30  srate         1000000 non-null  float64
#  31  drate         1000000 non-null  float64
#  32  attack        1000000 non-null  int64
#  33  category      1000000 non-null  object
#  34  subcategory   1000000 non-null  object
# dtypes: float64(17), int64(9), object(9)
# memory usage: 267.0+ MB

# %%
df.describe()
# Out:
#               pkSeqID         stime            pkts         bytes  \
# count  1000000.000000  1.000000e+06  1000000.000000  1.000000e+06
# mean    500000.500000  1.526826e+09        8.025125  5.156971e+03
# std     288675.278932  1.940616e+05      494.350757  4.781051e+05
# min          1.000000  1.526344e+09        1.000000  6.000000e+01
# 25%     250000.750000  1.526881e+09        2.000000  1.200000e+02
# 50%     500000.500000  1.526899e+09        2.000000  1.200000e+02
# 75%     750000.250000  1.526899e+09        2.000000  1.200000e+02
# max    1000000.000000  1.526949e+09    72700.000000  7.351081e+07
#
#               ltime             seq             dur            mean  \
# count  1.000000e+06  1000000.000000  1000000.000000  1000000.000000
# mean   1.526826e+09    98125.347005        1.906129        0.035261
# std    1.940582e+05    85446.184445       41.992245        0.203744
# min    1.526344e+09        1.000000        0.000000        0.000000
# 25%    1.526881e+09    15573.000000        0.000207        0.000200
# 50%    1.526899e+09    81392.000000        0.012066        0.011737
# 75%    1.526899e+09   164726.000000        0.035779        0.035538
# max    1.526950e+09   283299.000000     1940.859253        4.968881
#
#                stddev  smac  ...  sco  dco           spkts           dpkts  \
# count  1000000.000000   0.0  ...  0.0  0.0  1000000.000000  1000000.000000
# mean         0.003090   NaN  ...  NaN  NaN        5.393684        2.631441
# std          0.076291   NaN  ...  NaN  NaN      331.263622      212.018190
# min          0.000000   NaN  ...  NaN  NaN        0.000000        0.000000
# 25%          0.000000   NaN  ...  NaN  NaN        1.000000        1.000000
# 50%          0.000000   NaN  ...  NaN  NaN        1.000000        1.000000
# 75%          0.000000   NaN  ...  NaN  NaN        1.000000        1.000000
# max          2.499505   NaN  ...  NaN  NaN    38081.000000    36350.000000
#
#              sbytes        dbytes          rate           srate  \
# count  1.000000e+06  1.000000e+06  1.000000e+06  1000000.000000
# mean   3.539547e+03  1.617424e+03  6.539687e+03      232.299716
# std    3.054851e+05  2.120604e+05  3.353803e+04     2971.115068
# min    0.000000e+00  0.000000e+00  0.000000e+00        0.000000
# 25%    6.000000e+01  6.000000e+01  2.475186e+01        0.000000
# 50%    6.000000e+01  6.000000e+01  5.368839e+01        0.000000
# 75%    6.000000e+01  6.000000e+01  1.508296e+03        0.000000
# max    3.774702e+07  3.695876e+07  1.250000e+06  1000000.000000
#
#                 drate          attack
# count  1000000.000000  1000000.000000
# mean       214.119254        0.998007
# std       2145.511374        0.044599
# min          0.000000        0.000000
# 25%          0.000000        1.000000
# 50%          0.000000        1.000000
# 75%          0.000000        1.000000
# max     500000.000000        1.000000
#
# [8 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# pkSeqID               0
# stime                 0
# flgs                  0
# proto                 0
# saddr                 0
# sport               487
# daddr                 0
# dport               487
# pkts                  0
# bytes                 0
# state                 0
# ltime                 0
# seq                   0
# dur                   0
# mean                  0
# stddev                0
# smac            1000000
# dmac            1000000
# sum                   0
# min                   0
# max                   0
# soui            1000000
# doui            1000000
# sco             1000000
# dco             1000000
# spkts                 0
# dpkts                 0
# sbytes                0
# dbytes                0
# rate                  0
# srate                 0
# drate                 0
# attack                0
# category              0
# subcategory           0
# dtype: int64

# %%
df.drop(['pkSeqID',"smac",'dmac','soui','doui','sco','dco'],axis=1)
# Out:
#                stime flgs proto            saddr  sport           daddr  \
# 0       1.526344e+09    e   arp    192.168.100.1    NaN   192.168.100.3
# 1       1.526344e+09    e   tcp    192.168.100.7    139   192.168.100.4
# 2       1.526344e+09    e   udp  192.168.100.149  51838  27.124.125.250
# 3       1.526344e+09    e   arp    192.168.100.4    NaN   192.168.100.7
# 4       1.526344e+09    e   udp   192.168.100.27  58999   192.168.100.1
# ...              ...  ...   ...              ...    ...             ...
# 999995  1.526949e+09    e   tcp  192.168.100.150  49731   192.168.100.3
# 999996  1.526949e+09    e   tcp  192.168.100.150  49731   192.168.100.3
# 999997  1.526949e+09    e   tcp  192.168.100.150  49731   192.168.100.3
# 999998  1.526949e+09    e   tcp  192.168.100.150  49731   192.168.100.3
# 999999  1.526949e+09    e   tcp  192.168.100.150  49731   192.168.100.3
#
#         dport  pkts  bytes state  ...  spkts  dpkts  sbytes  dbytes  \
# 0         NaN     4    240   CON  ...      2      2     120     120
# 1       36390    10    680   CON  ...      5      5     350     330
# 2         123     2    180   CON  ...      1      1      90      90
# 3         NaN    10    510   CON  ...      5      5     210     300
# 4          53     4    630   CON  ...      2      2     174     456
# ...       ...   ...    ...   ...  ...    ...    ...     ...     ...
# 999995  12020     2    120   RST  ...      1      1      60      60
# 999996  60532     2    120   RST  ...      1      1      60      60
# 999997  52144     2    120   RST  ...      1      1      60      60
# 999998  58105     2    120   RST  ...      1      1      60      60
# 999999  16416     2    120   RST  ...      1      1      60      60
#
#              rate     srate     drate  attack        category  subcategory
# 0        0.002508  0.000836  0.000836       0          Normal        Normal
# 1        0.006190  0.002751  0.002751       0          Normal        Normal
# 2       20.590960  0.000000  0.000000       0          Normal        Normal
# 3        0.006189  0.002751  0.002751       0          Normal        Normal
# 4        0.005264  0.001755  0.001755       0          Normal        Normal
# ...           ...       ...       ...     ...             ...           ...
# 999995  23.854963  0.000000  0.000000       1  Reconnaissance  Service_Scan
# 999996  23.854963  0.000000  0.000000       1  Reconnaissance  Service_Scan
# 999997  23.862362  0.000000  0.000000       1  Reconnaissance  Service_Scan
# 999998  23.854963  0.000000  0.000000       1  Reconnaissance  Service_Scan
# 999999  23.854393  0.000000  0.000000       1  Reconnaissance  Service_Scan
#
# [1000000 rows x 28 columns]

# %%
df_c=df.describe().columns

# %%
df_int=df[df_c]

# %%
df_int.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 26 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   pkSeqID  1000000 non-null  int64
#  1   stime    1000000 non-null  float64
#  2   pkts     1000000 non-null  int64
#  3   bytes    1000000 non-null  int64
#  4   ltime    1000000 non-null  float64
#  5   seq      1000000 non-null  int64
#  6   dur      1000000 non-null  float64
#  7   mean     1000000 non-null  float64
#  8   stddev   1000000 non-null  float64
#  9   smac     0 non-null        float64
#  10  dmac     0 non-null        float64
#  11  sum      1000000 non-null  float64
#  12  min      1000000 non-null  float64
#  13  max      1000000 non-null  float64
#  14  soui     0 non-null        float64
#  15  doui     0 non-null        float64
#  16  sco      0 non-null        float64
#  17  dco      0 non-null        float64
#  18  spkts    1000000 non-null  int64
#  19  dpkts    1000000 non-null  int64
#  20  sbytes   1000000 non-null  int64
#  21  dbytes   1000000 non-null  int64
#  22  rate     1000000 non-null  float64
#  23  srate    1000000 non-null  float64
#  24  drate    1000000 non-null  float64
#  25  attack   1000000 non-null  int64
# dtypes: float64(17), int64(9)
# memory usage: 198.4 MB

# %%
df_int.isnull().sum()
# Out:
# pkSeqID          0
# stime            0
# pkts             0
# bytes            0
# ltime            0
# seq              0
# dur              0
# mean             0
# stddev           0
# smac       1000000
# dmac       1000000
# sum              0
# min              0
# max              0
# soui       1000000
# doui       1000000
# sco        1000000
# dco        1000000
# spkts            0
# dpkts            0
# sbytes           0
# dbytes           0
# rate             0
# srate            0
# drate            0
# attack           0
# dtype: int64

# %%
df_int.drop(['pkSeqID',"smac",'dmac','soui','doui','sco','dco'],axis=1,inplace=True)
# Out:
# /tmp/ipykernel_185/3921924913.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_int.drop(['pkSeqID',"smac",'dmac','soui','doui','sco','dco'],axis=1,inplace=True)

# %%
df_int.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 19 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   stime   1000000 non-null  float64
#  1   pkts    1000000 non-null  int64
#  2   bytes   1000000 non-null  int64
#  3   ltime   1000000 non-null  float64
#  4   seq     1000000 non-null  int64
#  5   dur     1000000 non-null  float64
#  6   mean    1000000 non-null  float64
#  7   stddev  1000000 non-null  float64
#  8   sum     1000000 non-null  float64
#  9   min     1000000 non-null  float64
#  10  max     1000000 non-null  float64
#  11  spkts   1000000 non-null  int64
#  12  dpkts   1000000 non-null  int64
#  13  sbytes  1000000 non-null  int64
#  14  dbytes  1000000 non-null  int64
#  15  rate    1000000 non-null  float64
#  16  srate   1000000 non-null  float64
#  17  drate   1000000 non-null  float64
#  18  attack  1000000 non-null  int64
# dtypes: float64(11), int64(8)
# memory usage: 145.0 MB

# %%
df_int.isnull().sum()
# Out:
# stime     0
# pkts      0
# bytes     0
# ltime     0
# seq       0
# dur       0
# mean      0
# stddev    0
# sum       0
# min       0
# max       0
# spkts     0
# dpkts     0
# sbytes    0
# dbytes    0
# rate      0
# srate     0
# drate     0
# attack    0
# dtype: int64

# %%
df_int.head()
# Out:
#           stime  pkts  bytes         ltime  seq          dur      mean  \
# 0  1.526344e+09     4    240  1.526345e+09    9  1195.996582  0.000006
# 1  1.526344e+09    10    680  1.526346e+09   10  1453.945923  0.000028
# 2  1.526344e+09     2    180  1.526344e+09   11     0.048565  0.048565
# 3  1.526344e+09    10    510  1.526346e+09   12  1454.080322  0.000238
# 4  1.526344e+09     4    630  1.526345e+09   14   569.933960  0.098505
#
#      stddev       sum       min       max  spkts  dpkts  sbytes  dbytes  \
# 0  0.000002  0.000011  0.000004  0.000007      2      2     120     120
# 1  0.000008  0.000138  0.000022  0.000042      5      5     350     330
# 2  0.000000  0.048565  0.048565  0.048565      1      1      90      90
# 3  0.000022  0.001189  0.000199  0.000261      5      5     210     300
# 4  0.080150  0.197011  0.018356  0.178655      2      2     174     456
#
#         rate     srate     drate  attack
# 0   0.002508  0.000836  0.000836       0
# 1   0.006190  0.002751  0.002751       0
# 2  20.590960  0.000000  0.000000       0
# 3   0.006189  0.002751  0.002751       0
# 4   0.005264  0.001755  0.001755       0

# %%
df_int.attack.value_counts()
# Out:
# attack
# 1    998007
# 0      1993
# Name: count, dtype: int64

# %%
df_int.columns
# Out:
# Index(['stime', 'pkts', 'bytes', 'ltime', 'seq', 'dur', 'mean', 'stddev',
#        'sum', 'min', 'max', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate',
#        'srate', 'drate', 'attack'],
#       dtype='object')

# %%
X=df_int.drop(['attack'],axis=1)
y=df_int['attack']

# %%
X.info(),print("\n\n"),y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 18 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   stime   1000000 non-null  float64
#  1   pkts    1000000 non-null  int64
#  2   bytes   1000000 non-null  int64
#  3   ltime   1000000 non-null  float64
#  4   seq     1000000 non-null  int64
#  5   dur     1000000 non-null  float64
#  6   mean    1000000 non-null  float64
#  7   stddev  1000000 non-null  float64
#  8   sum     1000000 non-null  float64
#  9   min     1000000 non-null  float64
#  10  max     1000000 non-null  float64
#  11  spkts   1000000 non-null  int64
#  12  dpkts   1000000 non-null  int64
#  13  sbytes  1000000 non-null  int64
#  14  dbytes  1000000 non-null  int64
#  15  rate    1000000 non-null  float64
#  16  srate   1000000 non-null  float64
#  17  drate   1000000 non-null  float64
# dtypes: float64(11), int64(7)
# memory usage: 137.3 MB
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000000 entries, 0 to 999999
# Series name: attack
# Non-Null Count    Dtype
# --------------    -----
# 1000000 non-null  int64
# dtypes: int64(1)
# memory usage: 7.6 MB
# (None, None, None)

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=2529,stratify=y)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# Check for multicollinearity
plt.figure(figsize=(18,10))

corr=X_train.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
def correlation(dataset, threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
# threshold--Domain expertise
corr_features=correlation(X_train,0.70)

# %%
corr_features
# Out:
# {'bytes', 'dbytes', 'dpkts', 'ltime', 'max', 'min', 'sbytes', 'spkts', 'sum'}

# %%
# drop features when correlation is more than 0.85
X_train.drop(corr_features,axis=1,inplace=True)
X_test.drop(corr_features,axis=1,inplace=True)
X_train.shape,X_test.shape
# Out:
# ((700000, 9), (300000, 9))

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
scaler=StandardScaler()
mm=MinMaxScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
## Plot desnity plot for all features
plt.style.use('seaborn')
pd.DataFrame(X_train_scaled).hist(bins=50,figsize=(20,15),color='orange')
plt.show()

# %%
plt.subplots(figsize=(30, 18))
plt.subplot(1, 2, 1)
sns.boxplot(data=X_train)
plt.title('X_train Before Scaling')
plt.subplot(1, 2, 2)
sns.boxplot(data=X_train_scaled)
plt.title('X_train After Scaling')
# Out:
# Text(0.5, 1.0, 'X_train After Scaling')

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.naive_bayes import BernoulliNB, GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from sklearn.metrics import accuracy_score, classification_report,ConfusionMatrixDisplay, \
                            precision_score, recall_score, f1_score, roc_auc_score,roc_curve,\
                            confusion_matrix

# %%
models={

    "Logisitic Regression":LogisticRegression(),
    "Decision Tree":DecisionTreeClassifier(),

    "Gradient Boost":GradientBoostingClassifier(),
    "Adaboost":AdaBoostClassifier(),
    "Xgboost":XGBClassifier(),
    "Gausian":GaussianNB(),
    "Bernoulli":BernoulliNB(),
    "knn"    :KNeighborsClassifier(),
    "Random Forest":RandomForestClassifier(),
    # "svm"    :SVC() we can't use svm because of high computation
}



for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train_scaled, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(X_train_scaled)
    y_test_pred = model.predict(X_test_scaled)



      # Training set performance
    model_train_accuracy = accuracy_score(y_train, y_train_pred) # Calculate Accuracy
    model_train_f1 = f1_score(y_train, y_train_pred) # Calculate F1-score
    model_train_precision = precision_score(y_train, y_train_pred) # Calculate Precision, add average='weighted'
    model_train_recall = recall_score(y_train, y_train_pred) # Calculate Recall, add average='weighted'
    model_train_rocauc_score = roc_auc_score(y_train, y_train_pred) #Calculate Roc, add multi_class='ovr'


    # Test set performance
    model_test_accuracy = accuracy_score(y_test, y_test_pred) # Calculate Accuracy
    model_test_f1 = f1_score(y_test, y_test_pred) # Calculate F1-score
    model_test_precision = precision_score(y_test, y_test_pred) # Calculate Precision, add average='weighted'
    model_test_recall = recall_score(y_test, y_test_pred) # Calculate Recall, add average='weighted'
    model_test_rocauc_score = roc_auc_score(y_test, y_test_pred) #Calculate Roc, add multi_class='ovr'


    print(list(models.keys())[i])

    print('Model performance for Training set')
    print("- Accuracy: {:.4f}".format(model_train_accuracy))
    print('- F1 score: {:.4f}'.format(model_train_f1))

    print('- Precision: {:.4f}'.format(model_train_precision))
    print('- Recall: {:.4f}'.format(model_train_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_train_rocauc_score))



    print('----------------------------------')

    print('Model performance for Test set')
    print('- Accuracy: {:.4f}'.format(model_test_accuracy))
    print('- F1 score: {:.4f}'.format(model_test_f1))
    print('- Precision: {:.4f}'.format(model_test_precision))
    print('- Recall: {:.4f}'.format(model_test_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_test_rocauc_score))


    print('='*35)
    print('\n')
# Out:
# Logisitic Regression
# Model performance for Training set
# - Accuracy: 0.9982
# - F1 score: 0.9991
# - Precision: 0.9982
# - Recall: 1.0000
# - Roc Auc Score: 0.5513
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9982
# - F1 score: 0.9991
# - Precision: 0.9982
# - Recall: 1.0000
# - Roc Auc Score: 0.5602
# ===================================
#
#
# Decision Tree
# Model performance for Training set
# - Accuracy: 1.0000
# - F1 score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9993
# - F1 score: 0.9997
# - Precision: 0.9996
# - Recall: 0.9997
# - Roc Auc Score: 0.9079
# ===================================
#
#
# Random Forest
# Model performance for Training set
# - Accuracy: 0.9999
# - F1 score: 1.0000
# - Precision: 0.9999
# - Recall: 1.0000
# - Roc Auc Score: 0.9853
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9995
# - F1 score: 0.9997
# - Precision: 0.9996
# - Recall: 0.9999
# - Roc Auc Score: 0.8996
# ===================================
#
#
# Gradient Boost
# Model performance for Training set
# - Accuracy: 0.9994
# - F1 score: 0.9997
# - Precision: 0.9994
# - Recall: 1.0000
# - Roc Auc Score: 0.8595
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9993
# - F1 score: 0.9996
# - Precision: 0.9994
# - Recall: 0.9999
# - Roc Auc Score: 0.8411
# ===================================
#
#
# Adaboost
# Model performance for Training set
# - Accuracy: 0.9987
# - F1 score: 0.9994
# - Precision: 0.9988
# - Recall: 0.9999
# - Roc Auc Score: 0.7003
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9987
# - F1 score: 0.9994
# - Precision: 0.9988
# - Recall: 0.9999
# - Roc Auc Score: 0.6956
# ===================================
#
#
# Xgboost
# Model performance for Training set
# - Accuracy: 0.9997
# - F1 score: 0.9998
# - Precision: 0.9997
# - Recall: 1.0000
# - Roc Auc Score: 0.9147
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9995
# - F1 score: 0.9998
# - Precision: 0.9996
# - Recall: 1.0000
# - Roc Auc Score: 0.8880
# ===================================
#
#
# Gausian
# Model performance for Training set
# - Accuracy: 0.9912
# - F1 score: 0.9956
# - Precision: 0.9984
# - Recall: 0.9928
# - Roc Auc Score: 0.5932
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9914
# - F1 score: 0.9957
# - Precision: 0.9984
# - Recall: 0.9930
# - Roc Auc Score: 0.6027
# ===================================
#
#
# Bernoulli
# Model performance for Training set
# - Accuracy: 0.9947
# - F1 score: 0.9973
# - Precision: 0.9983
# - Recall: 0.9964
# - Roc Auc Score: 0.5674
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9947
# - F1 score: 0.9974
# - Precision: 0.9983
# - Recall: 0.9964
# - Roc Auc Score: 0.5793
# ===================================
#
#
# knn
# Model performance for Training set
# - Accuracy: 0.9994
# - F1 score: 0.9997
# - Precision: 0.9994
# - Recall: 0.9999
# - Roc Auc Score: 0.8605
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9992
# - F1 score: 0.9996
# - Precision: 0.9993
# - Recall: 0.9999
# - Roc Auc Score: 0.8352
# ===================================
